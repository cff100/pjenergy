# %% [markdown]
# <a href="https://colab.research.google.com/github/cff100/pjenergy/blob/refactor%2Farquitetura/examples/quickstart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip uninstall -y pjenergy
# %pip install "git+https://github.com/cff100/pjenergy.git@refactor/arquitetura"

# %%
url = "" # @param {"type":"string","placeholder":"Insert url here"}
key = "" # @param {"type":"string","placeholder":"Insert key here"}

# %%
from pjenergy.era5.client import create_cdsapi_client_doc
create_cdsapi_client_doc(url=url, key=key)

# %%
from pjenergy.era5.parameters import download_parameters_from_github
download_parameters_from_github()

# %%
from pjenergy.era5.request import request_era5
request_era5()
