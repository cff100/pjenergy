# %%
# %pip uninstall -y pjenergy
# %pip install "git+https://github.com/cff100/pjenergy.git@refactor/arquitetura"
# Out:
# A execução de células com 'ambiente_pjenergy (Python 3.12.12)' requer o pacote ipykernel.
#
# Instale 'ipykernel' no ambiente Python.
#
# Comando: 'conda install -n ambiente_pjenergy ipykernel --update-deps --force-reinstall'

# %%
url = "Adicione url aqui" #@param {type:"string"}
key = "Adicione key aqui"  #@param {type:"string"}

# %%
from pjenergy.era5.client import create_era5_client_doc
create_era5_client_doc(url=url, key=key)

# %%
from pjenergy.era5.parameters import download_parameters_from_github
download_parameters_from_github()

# %%
from pjenergy.era5.request import request_era5
request_era5()
